# %%
# !pip install ultralytics

from ultralytics import YOLO
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 61.9 MB/s eta 0:00:00
# ...
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

# Ruta donde quieres guardar (puedes cambiar "MyDrive" si usas otra carpeta)
ruta = "/content/drive/MyDrive/ppe"

# Crear carpeta si no existe
os.makedirs(ruta, exist_ok=True)

# Cambiar el directorio de trabajo
os.chdir(ruta)

# Verificar
print("Directorio actual:", os.getcwd())
# Out:
# Directorio actual: /content/drive/MyDrive/ppe

# %%
# !pip install roboflow

from roboflow import Roboflow
import os

# Definir ruta en tu Drive
ruta_base = "/content/drive/MyDrive/ppe"
ruta_dataset = os.path.join(ruta_base, "dataset")

# Crear carpeta si no existe
os.makedirs(ruta_dataset, exist_ok=True)

# Cambiar directorio a donde quieres que se descargue
os.chdir(ruta_dataset)

print("Descargando en:", os.getcwd())

# Descargar dataset desde Roboflow
rf = Roboflow(api_key="dSMfDD4uPaMCKEoGOP5q")
project = rf.workspace("cicatriz").project("ppe-factory-bmdcj-alnpk")
version = project.version(1)

dataset = version.download("yolov8")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 175.9/175.9 kB 6.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 3.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 19.5 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 72.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 108.8 MB/s eta 0:00:0000:01
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.13.0.92
#     Uninstalling opencv-python-headless-4.13.0.92:
#       Successfully uninstalled opencv-python-headless-4.13.0.92
#   Attempting uninstall: idna
#     Found existing installation: idna 3.11
#     Uninstalling idna-3.11:
#       Successfully uninstalled idna-3.11
# ...
# Descargando en: /content/drive/MyDrive/ppe/dataset
# loading Roboflow workspace...
# loading Roboflow project...
# ...

# %%
from ultralytics import YOLO

# Ruta al data.yaml (ajústala si cambió el nombre de la carpeta)
data_yaml = "/content/drive/MyDrive/ppe/dataset/ppe-factory-1/data.yaml"

# Cargar modelo base
model = YOLO("yolov8n.pt")

# Entrenar y guardar resultados en variable
resultado = model.train(
    data=data_yaml,
    epochs=5,        # puedes ajustar (ej: 30, 100)
    imgsz=640,
    batch=16,
    project="/content/drive/MyDrive/ppe",  # se guarda en tu Drive
    name="ejecuciones",
    save=True
)

print("Entrenamiento finalizado")
# Out:
# ...
# Ultralytics 8.4.41 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...
